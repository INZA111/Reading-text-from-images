# %%
import matplotlib.pyplot as plt
import keras_ocr

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for C:\Users\DELL\.keras-ocr\craft_mlt_25k.h5
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py:5783: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# Looking for C:\Users\DELL\.keras-ocr\crnn_kurapan.h5

# %%
images = [
    keras_ocr.tools.read(images) for images in ['car.png',
                                                'car1.png',
                                                'car2.png'

        
    ]
]

# %%
prediction = pipeline.recognize(images)

# %%
prediction
# Out:
# [[('dlasc',
#    array([[289., 111.],
#           [371., 111.],
#           [371., 128.],
#           [289., 128.]], dtype=float32)),
#   ('ars',
#    array([[287., 131.],
#           [326., 131.],
#           [326., 147.],
#           [287., 147.]], dtype=float32)),
#   ('0200',
#    array([[342., 131.],
#           [398., 131.],
#           [398., 149.],
#           [342., 149.]], dtype=float32)),
#   ('ssars',
#    array([[541., 134.],
#           [582., 134.],
#           [582., 144.],
#           [541., 144.]], dtype=float32))],
#  [('3751',
#    array([[358., 289.],
#           [418., 289.],
#           [418., 309.],
#           [358., 309.]], dtype=float32)),
#   ('up54',
#    array([[261.64813, 291.11148],
#           [327.8902 , 289.7314 ],
#           [328.31708, 310.2225 ],
#           [262.075  , 311.60257]], dtype=float32)),
#   ('u',
#    array([[337., 292.],
#           [352., 292.],
#           [352., 309.],
#           [337., 309.]], dtype=float32))],
#  [('ced',
#    array([[407.43115 , 106.064026],
#           [481.79706 , 103.02869 ],
#           [482.55048 , 121.48773 ],
#           [408.18457 , 124.52307 ]], dtype=float32)),
#   ('oclzes',
#    array([[343.1671 , 146.22826],
#           [511.7544 , 135.23344],
#           [512.7666 , 150.75438],
#           [344.17932, 161.74919]], dtype=float32)),
#   ('ss',
#    array([[552.6118 , 140.95294],
#           [592.8353 , 137.85883],
#           [593.44116, 145.73529],
#           [553.21765, 148.8294 ]], dtype=float32)),
#   ('to',
#    array([[247., 161.],
#           [259., 161.],
#           [259., 167.],
#           [247., 167.]], dtype=float32))]]

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
# Out:
# C:\Anaconda3\lib\site-packages\keras_ocr\tools.py:166: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   horizontalalignment='right' if side == 'left' else 'left')

# %%
detector = keras_ocr.detection.Detector()
recognizer = keras_ocr.recognition.Recognizer()

pipeline = keras_ocr.pipeline.Pipeline(detector=detector,recognizer=recognizer)
prediction = pipeline.recognize(images)
# Out:
# Looking for C:\Users\DELL\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\DELL\.keras-ocr\crnn_kurapan.h5

# %%
prediction
# Out:
# [[('dlasc',
#    array([[289., 111.],
#           [371., 111.],
#           [371., 128.],
#           [289., 128.]], dtype=float32)),
#   ('ars',
#    array([[287., 131.],
#           [326., 131.],
#           [326., 147.],
#           [287., 147.]], dtype=float32)),
#   ('0200',
#    array([[342., 131.],
#           [398., 131.],
#           [398., 149.],
#           [342., 149.]], dtype=float32)),
#   ('ssars',
#    array([[541., 134.],
#           [582., 134.],
#           [582., 144.],
#           [541., 144.]], dtype=float32))],
#  [('3751',
#    array([[358., 289.],
#           [418., 289.],
#           [418., 309.],
#           [358., 309.]], dtype=float32)),
#   ('up54',
#    array([[261.64813, 291.11148],
#           [327.8902 , 289.7314 ],
#           [328.31708, 310.2225 ],
#           [262.075  , 311.60257]], dtype=float32)),
#   ('u',
#    array([[337., 292.],
#           [352., 292.],
#           [352., 309.],
#           [337., 309.]], dtype=float32))],
#  [('ced',
#    array([[407.43115 , 106.064026],
#           [481.79706 , 103.02869 ],
#           [482.55048 , 121.48773 ],
#           [408.18457 , 124.52307 ]], dtype=float32)),
#   ('oclzes',
#    array([[343.1671 , 146.22826],
#           [511.7544 , 135.23344],
#           [512.7666 , 150.75438],
#           [344.17932, 161.74919]], dtype=float32)),
#   ('ss',
#    array([[552.6118 , 140.95294],
#           [592.8353 , 137.85883],
#           [593.44116, 145.73529],
#           [553.21765, 148.8294 ]], dtype=float32)),
#   ('to',
#    array([[247., 161.],
#           [259., 161.],
#           [259., 167.],
#           [247., 167.]], dtype=float32))]]

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
# Out:
# C:\Anaconda3\lib\site-packages\keras_ocr\tools.py:166: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   horizontalalignment='right' if side == 'left' else 'left')
